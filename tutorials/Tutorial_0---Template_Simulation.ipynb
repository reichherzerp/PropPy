# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
os.chdir('..')
import proppy as pp

# %%
sim = pp.IsotropicSimulation()
# %time sim.simulate()
#sim.get_simulation_info()
# Out:
# mfp_ios 10006671114076.05
# simulate with a diffusion coefficient of  1e+21 m²/s
# start simulation
# Propagator initialized
# Observer initialized
# saved data file isotropic.pkl
# CPU times: user 30 s, sys: 558 ms, total: 30.6 s
# Wall time: 30.6 s

# %%
df = pd.read_pickle("isotropic.pkl")
sta = pp.Statistics(df)
df_kappas = sta.plot_diffusion_coefficients(n_points_plateau=100)
# Out:
# init statistics plotting class
# diffusion coefficients computed between 2.18e+15m and 1.00e+16m with 100 data points
# kappa_{xx}: 9.11e+20 m²/s +- 2.18e+19 m²/s
# kappa_{yy}: 9.32e+20 m²/s +- 2.64e+19 m²/s
# kappa_{zz}: 9.98e+20 m²/s +- 1.83e+19 m²/s

# %%
sim = pp.AnisotropicSimulation()
# %time sim.simulate()
# Out:
# simulate with a diffusion coefficient of  1.3999999999999998e+20 m²/s
# start simulation
# Propagator initialized
# Observer initialized
# saved data file anisotropic.pkl
# CPU times: user 18.8 s, sys: 8.09 ms, total: 18.8 s
# Wall time: 18.8 s

# %%
df = pd.read_pickle("anisotropic.pkl")
sta = pp.Statistics(df)
df_kappas = sta.plot_diffusion_coefficients(n_points_plateau=100)
# Out:
# init statistics plotting class
# diffusion coefficients computed between 1.49e+13m and 1.00e+14m with 100 data points
# kappa_{xx}: 9.72e+16 m²/s +- 1.45e+16 m²/s
# kappa_{yy}: 6.77e+16 m²/s +- 9.01e+15 m²/s
# kappa_{zz}: 1.29e+20 m²/s +- 1.15e+19 m²/s
